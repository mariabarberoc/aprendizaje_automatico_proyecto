# %%
#!pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("salvatorerastelli/spotify-and-youtube")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\propietario\.cache\kagglehub\datasets\salvatorerastelli\spotify-and-youtube\versions\2

# %%
import pandas as pd
import os
import seaborn as sns

# %%
spotify_youtube_df = pd.read_csv(os.path.join(path, "Spotify_Youtube.csv"))

# %% [markdown]
# Vamos a echar un primer vistazo a los datos:

# %%
spotify_youtube_df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri  Danceability  Energy   Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0  ...
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0  ...
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0  ...
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0  ...
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  https://www.youtube.com/watch?v=yYDmaexVHic
# 2  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#    Licensed official_video        Stream
# 0      True           True  1.040235e+09
# 1      True           True  3.100837e+08
# 2      True           True  6.306347e+07
# 3      True           True  4.346636e+08
# 4      True           True  6.172597e+08
#
# [5 rows x 28 columns]

# %%
spotify_youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
#  16  Tempo             20716 non-null  float64
#  17  Duration_ms       20716 non-null  float64
#  18  Url_youtube       20248 non-null  object
#  19  Title             20248 non-null  object
#  20  Channel           20248 non-null  object
#  21  Views             20248 non-null  float64
#  22  Likes             20177 non-null  float64
#  23  Comments          20149 non-null  float64
#  24  Description       19842 non-null  object
#  25  Licensed          20248 non-null  object
#  26  official_video    20248 non-null  object
#  27  Stream            20142 non-null  float64
# dtypes: float64(15), int64(1), object(12)
# memory usage: 4.4+ MB

# %%
spotify_youtube_df.describe()
# Out:
#          Unnamed: 0  Danceability        Energy           Key      Loudness  \
# count  20718.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean   10358.500000      0.619777      0.635250      5.300348     -7.671680
# std     5980.915774      0.165272      0.214147      3.576449      4.632749
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5179.250000      0.518000      0.507000      2.000000     -8.858000
# 50%    10358.500000      0.637000      0.666000      5.000000     -6.536000
# 75%    15537.750000      0.740250      0.798000      8.000000     -4.931000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  20716.000000  20716.000000      20716.000000  20716.000000
# mean       0.096456      0.291535          0.055962      0.193521
# std        0.111960      0.286299          0.193262      0.168531
# min        0.000000      0.000001          0.000000      0.014500
# 25%        0.035700      0.045200          0.000000      0.094100
# 50%        0.050500      0.193000          0.000002      0.125000
# 75%        0.103000      0.477250          0.000463      0.237000
# max        0.964000      0.996000          1.000000      1.000000
#
#             Valence         Tempo   Duration_ms         Views         Likes  \
# count  20716.000000  20716.000000  2.071600e+04  2.024800e+04  2.017700e+04
# mean       0.529853    120.638340  2.247176e+05  9.393782e+07  6.633411e+05
# std        0.245441     29.579018  1.247905e+05  2.746443e+08  1.789324e+06
# min        0.000000      0.000000  3.098500e+04  0.000000e+00  0.000000e+00
# 25%        0.339000     97.002000  1.800095e+05  1.826002e+06  2.158100e+04
# 50%        0.537000    119.965000  2.132845e+05  1.450110e+07  1.244810e+05
# 75%        0.726250    139.935000  2.524430e+05  7.039975e+07  5.221480e+05
# max        0.993000    243.372000  4.676058e+06  8.079649e+09  5.078865e+07
#
#            Comments        Stream
# count  2.014900e+04  2.014200e+04
# mean   2.751899e+04  1.359422e+08
# std    1.932347e+05  2.441321e+08
# min    0.000000e+00  6.574000e+03
# 25%    5.090000e+02  1.767486e+07
# 50%    3.277000e+03  4.968298e+07
# 75%    1.436000e+04  1.383581e+08
# max    1.608314e+07  3.386520e+09

# %%
spotify_youtube_df.isnull().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# Tras revisar el dataset, las siguientes columnas no aportan información útil para el EDA ni para el modelado y pueden eliminarse:
#
# ⁠Unnamed: 0 → índice exportado por error
# ⁠Url_spotify → enlace, no aporta información analítica
# ⁠Url_youtube → enlace, no aporta información analítica
# ⁠Uri → identificador interno sin valor analítico
# ⁠Description → texto libre, muy incompleto y no cuantitativo
# Title → Identificador de la canción de youtube, ya tenemos esos datos recogidos antes con la columna track
# Channel → canal de youtube del vídeo, no aporta información analítica

# %%
spotify_youtube_df= spotify_youtube_df.drop(['Unnamed: 0', 'Url_spotify', 'Url_youtube', 'Uri', 'Description','Title', 'Channel'],axis=1)

# %%
spotify_youtube_df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness',
#        'Liveness', 'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes',
#        'Comments', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# ## Vamos a estudiar las columnas y los datos que nos aportan:

# %% [markdown]
# ### Artist, Track y Album
# Columnas que identifican de manera única cada dato. Además, como podemos ver anteriormente,  no tienen valores nulos luego no necesitamos modificarlas ni eliminarlas

# %% [markdown]
# ### Album_type
# La columna nos indica cómo se ha sacado la canción (como single, album o recopilación), de esta forma, podemos obtener informacion útil sobre la mejor manera de sacar una canción para que triunfe

# %%
spotify_youtube_df['Album_type'].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
spotify_youtube_df['Album_type'].value_counts()
# Out:
# Album_type
# album          14926
# single          5004
# compilation      788
# Name: count, dtype: int64

# %% [markdown]
# ### Danceability
# Permite ver cómo de buena es una canción para bailarla, los datos se recogen entre 0 y 1

# %%
spotify_youtube_df['Danceability'].describe()
# Out:
# count    20716.000000
# mean         0.619777
# std          0.165272
# min          0.000000
# 25%          0.518000
# 50%          0.637000
# 75%          0.740250
# max          0.975000
# Name: Danceability, dtype: float64

# %% [markdown]
# Corroboramos que no tenemos datos fuera del rango pues se ve el mínimo es 0 y el máximo 0.975

# %% [markdown]
# ### Energy
# Mide la energia en el rango [0.0 ; 1.0] representa la intensidad y la actividad, en funcion de si ees más energetico, ruidoso o alta.
# Musica clasica tendrá valores mas cercanos a 0

# %%
spotify_youtube_df[
    (spotify_youtube_df["Energy"] < 0) |
    (spotify_youtube_df["Energy"] > 1)
]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# No hay valores fuera de rango (también podíamos haber visto el .describe)

# %% [markdown]
# ### Key
# Esta columna recoge la tonalidad en la que está la pista. Sigue la notación Pitch Class.
# Por ejemplo, 0 = C, 1 = C♯/D♭, 2 = D, y así sucesivamente.
# Si no se detecta ninguna tonalidad, el valor es -1.

# %%
spotify_youtube_df['Key'].value_counts()
# Out:
# Key
# 0.0     2305
# 7.0     2252
# 1.0     2211
# 2.0     2021
# 9.0     1979
# 5.0     1731
# 11.0    1667
# 4.0     1515
# 8.0     1483
# 6.0     1443
# 10.0    1439
# 3.0      670
# Name: count, dtype: int64

# %% [markdown]
# Vemos que no está el valor -1, luego no hay missing values.
# Como esta columna nos da en realidad una tonalidad, no nos interesa que esté en tipo float porque ocupa espacio de almacenamiento y solo tiene números enteros. Vamos a sustituirlo directamente por el tono musical al que corresponde el número.

# %%
diccionario_notas = {
    0: "C",
    1: "C# / Db",
    2: "D",
    3: "D# / Eb",
    4: "E",
    5: "F",
    6: "F# / Gb",
    7: "G",
    8: "G# / Ab",
    9: "A",
    10: "A# / Bb",
    11: "B"
}

# %%
spotify_youtube_df["Key"] = spotify_youtube_df["Key"].replace(diccionario_notas)
spotify_youtube_df['Key'].value_counts()
# Out:
# Key
# C          2305
# G          2252
# C# / Db    2211
# D          2021
# A          1979
# F          1731
# B          1667
# E          1515
# G# / Ab    1483
# F# / Gb    1443
# A# / Bb    1439
# D# / Eb     670
# Name: count, dtype: int64

# %% [markdown]
# ### Loudness
# Representa la sonoridad global de una canción medida en decibelios (dB). Este valor se calcula como una media a lo largo de toda la pista y permite comparar la intensidad sonora entre diferentes canciones.
# Los valores de Loudness suelen estar comprendidos entre –60 dB y 0 dB:
# ⁠Canciones con valores alrededor de –60 dB son muy suaves o acústicas.
# ⁠Canciones con valores cercanos a 0 dB son muy intensas, comprimidas y típicas de géneros más comerciales o electrónicos.

# %%
spotify_youtube_df["Loudness"].describe()
# Out:
# count    20716.000000
# mean        -7.671680
# std          4.632749
# min        -46.251000
# 25%         -8.858000
# 50%         -6.536000
# 75%         -4.931000
# max          0.920000
# Name: Loudness, dtype: float64

# %%
spotify_youtube_df[
    (spotify_youtube_df["Loudness"] < -60) |
    (spotify_youtube_df["Loudness"]  > 0)
]
# Out:
#                        Artist  \
# 9423                Sub Focus
# 10578  Sergio Vega "El Shaka"
# 11826                 Cascada
# 12543          French Montana
# 15187              Shilpi Raj
# 18354            Montell Fish
#
#                                                    Track  \
# 9423                                               Siren
# 10578                             Me Gusta Estar Contigo
# 11826        Everytime We Touch - Fallen Superhero Remix
# 12543  Welcome to the Party (with French Montana & Li...
# 15187                               Le Le Aayi Coca Cola
# 18354                                            Exscape
#
#                                                    Album Album_type  \
# 9423                                Solar System / Siren     single
# 10578                             Me Gusta Estar Contigo      album
# 11826        Everytime We Touch (Fallen Superhero Remix)     single
# 12543  Welcome to the Party (with French Montana & Li...     single
# 15187                               Le Le Aayi Coca Cola     single
# 18354              Her Love Still Haunts Me Like a Ghost      album
#
#        Danceability  Energy      Key  Loudness  Speechiness  Acousticness  \
# 9423          0.486   0.986        F     0.920       0.0620        0.1180
# 10578         0.888   0.741        F     0.522       0.0573        0.4950
# 11826         0.610   0.971  F# / Gb     0.006       0.1690        0.0641
# 12543         0.618   0.845        D     0.175       0.1320        0.1140
# 15187         0.716   0.962        F     0.561       0.1010        0.3570
# 18354         0.599   0.854        E     0.829       0.0373        0.6480
#
#        ...  Liveness  Valence    Tempo  Duration_ms        Views      Likes  \
# 9423   ...    0.2190    0.241  173.983     256000.0    1042170.0    16584.0
# 10578  ...    0.0533    0.968  105.789     138467.0    4976974.0     6740.0
# 11826  ...    0.3380    0.487  150.089     218587.0    6967544.0    59878.0
# 12543  ...    0.4150    0.486  171.921     181720.0  207546580.0  2385757.0
# 15187  ...    0.1890    0.857  114.993     277569.0  327570837.0  2109990.0
# 18354  ...    0.0980    0.449  139.995     142286.0     361642.0     8318.0
#
#        Comments  Licensed official_video       Stream
# 9423      329.0      True           True   14126273.0
# 10578     191.0     False          False   25302700.0
# 11826     636.0     False          False   12159973.0
# 12543   69474.0     False           True  238992070.0
# 15187  107962.0      True           True    3667356.0
# 18354     226.0     False           True    7762624.0
#
# [6 rows x 21 columns]

# %% [markdown]
# Estas seis filas deben eliminarse porque los valores de Loudness están fuera del rango válido para una canción (–60 dB a 0 dB), por
# tanto, representan datos erróneos y eliminarlos mejora la calidad del análisis.

# %%
spotify_youtube_df = spotify_youtube_df[(spotify_youtube_df['Loudness'] >= -60) & (spotify_youtube_df['Loudness'] <= 0)]

# %% [markdown]
# ### Speechiness
# Esta columna nos indica la presencia de palabras en una canción, los valores cercanos a 1 son las pistas completamente habladas, como por ejemplo un audio libro.
# los valores en el rango [0.33 ; 0.66] combinan música y voz, por otro lado los valores por debajo de 0.33, su contenido sera principalmente musical.
# Esto es especialmente útil si queremos filtrar o segmentar canciones según su estilo o presencia de voz hablada, no modificamos el contenido

# %%
spotify_youtube_df[
    (spotify_youtube_df["Speechiness"] < 0) |
    (spotify_youtube_df["Speechiness"] > 1)
]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 21 columns]

# %%
spotify_youtube_df['Speechiness'].describe()
# Out:
# count    20710.000000
# mean         0.096457
# std          0.111973
# min          0.000000
# 25%          0.035700
# 50%          0.050500
# 75%          0.103000
# max          0.964000
# Name: Speechiness, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df['Speechiness'] == spotify_youtube_df['Speechiness'].min()]
# Out:
#                        Artist  \
# 2073          Louis Armstrong
# 2871            The Alchemist
# 7187        Luciano Pavarotti
# 8373                      M83
# 9266                Lang Lang
# 9348             Ocean Sounds
# 9358    Ocean Waves For Sleep
# 13839  White Noise for Babies
# 13840  White Noise for Babies
# 13842  White Noise for Babies
# 13844  White Noise for Babies
# 13845  White Noise for Babies
# 13848  White Noise for Babies
# 15588  White Noise Baby Sleep
# 15590  White Noise Baby Sleep
# 15595  White Noise Baby Sleep
# 15597  White Noise Baby Sleep
#
#                                                    Track  \
# 2073                                       Hello, Dolly!
# 2871                                             Arrival
# 7187       Rigoletto / Act 3: "La donna è mobile" - Live
# 8373                                              Adieux
# 9266                                       The Departure
# 9348                Beach Waves and Soothing Brown Noise
# 9358                Beach Waves and Soothing Brown Noise
# 13839          Clean White Noise - Loopable with no fade
# 13840           Pure Brown Noise - Loopable with no fade
# 13842            Air Conditioner - Loopable with no fade
# 13844               Shower Sound - Loopable Without Fade
# 13845           Soothing White Noise - Loopable, No Fade
# 13848              Clean White Noise - Loopable, No Fade
# 15588          Clean White Noise - Loopable with no fade
# 15590           Pure Brown Noise - Loopable with no fade
# 15595  White Noise Relaxation for Calming Down Fussy ...
# 15597            Air Conditioner - Loopable with no fade
#
#                                                    Album   Album_type  \
# 2073                          Hello, Dolly! (Remastered)        album
# 2871                                       Israeli Salad        album
# 7187         The Three Tenors - The Best of the 3 Tenors  compilation
# 8373                                   You And The Night        album
# 9266                     Voyager - Essential Max Richter        album
# 9348   Soothing Brown Noise Waves and Calming Ambient...        album
# 9358   Soothing Brown Noise Waves and Calming Ambient...        album
# 13839  Best White Noise for Baby Sleep - Loopable wit...        album
# 13840  Best White Noise for Baby Sleep - Loopable wit...        album
# 13842  Best White Noise for Baby Sleep - Loopable wit...        album
# 13844                                        White Noise        album
# 13845                                        White Noise        album
# 13848                      Relaxing Loopable White Noise       single
# 15588  Best White Noise for Baby Sleep - Loopable wit...        album
# 15590  Best White Noise for Baby Sleep - Loopable wit...        album
# 15595                    White Noise for Sleeping Babies        album
# 15597  Best White Noise for Baby Sleep - Loopable wit...        album
#
#        Danceability    Energy      Key  Loudness  Speechiness  Acousticness  \
# 2073            0.0  0.405000        C    -9.935          0.0       0.84200
# 2871            0.0  0.802000  C# / Db    -7.977          0.0       0.00417
# 7187            0.0  0.402000        F   -15.718          0.0       0.97200
# 8373            0.0  0.105000        G   -13.925          0.0       0.98900
# 9266            0.0  0.036200        C   -22.519          0.0       0.99400
# 9348            0.0  0.000252        A   -17.746          0.0       0.00948
# 9358            0.0  0.000252        A   -17.746          0.0       0.00948
# 13839           0.0  0.003420  G# / Ab   -28.460          0.0       0.79100
# 13840           0.0  0.001250  C# / Db   -27.592          0.0       0.90800
# 13842           0.0  0.000055  A# / Bb   -21.995          0.0       0.92100
# 13844           0.0  0.251000        D   -25.004          0.0       0.11900
# 13845           0.0  0.001250  C# / Db   -27.592          0.0       0.90800
# 13848           0.0  0.003420  G# / Ab   -28.460          0.0       0.79100
# 15588           0.0  0.003420  G# / Ab   -28.460          0.0       0.79100
# 15590           0.0  0.001250  C# / Db   -27.592          0.0       0.90800
# 15595           0.0  0.373000  A# / Bb   -16.469          0.0       0.15300
# 15597           0.0  0.000055  A# / Bb   -21.995          0.0       0.92100
#
#        ...  Liveness  Valence  Tempo  Duration_ms        Views     Likes  \
# 2073   ...    0.1980      0.0    0.0     147000.0   12691825.0   98026.0
# 2871   ...    0.6030      0.0    0.0      94967.0     104635.0    1905.0
# 7187   ...    0.8970      0.0    0.0     151253.0   31017254.0  204651.0
# 8373   ...    0.1080      0.0    0.0      64840.0      50330.0     453.0
# 9266   ...    0.0958      0.0    0.0     151507.0     185634.0    1796.0
# 9348   ...    0.8060      0.0    0.0      93452.0        328.0       1.0
# 9358   ...    0.8060      0.0    0.0      93452.0        328.0       1.0
# 13839  ...    0.1110      0.0    0.0      90228.0       1492.0      18.0
# 13840  ...    0.1110      0.0    0.0      72223.0    2329675.0   11249.0
# 13842  ...    0.1140      0.0    0.0     108527.0        407.0       1.0
# 13844  ...    0.3840      0.0    0.0      62850.0      17140.0      40.0
# 13845  ...    0.1110      0.0    0.0      72223.0  157884163.0  483072.0
# 13848  ...    0.1110      0.0    0.0      90228.0       1492.0      18.0
# 15588  ...    0.1110      0.0    0.0      90228.0       1492.0      18.0
# 15590  ...    0.1110      0.0    0.0      72223.0     290014.0     674.0
# 15595  ...    0.7260      0.0    0.0     593754.0     376087.0     561.0
# 15597  ...    0.1140      0.0    0.0     108527.0        407.0       1.0
#
#        Comments  Licensed official_video       Stream
# 2073     4050.0     False          False   22358910.0
# 2871       21.0      True           True    9283211.0
# 7187     9002.0     False          False    1995393.0
# 8373       11.0      True           True    3387203.0
# 9266       20.0      True           True   11902123.0
# 9348        0.0      True           True   54256600.0
# 9358        0.0      True           True   54256600.0
# 13839       0.0      True           True  956435715.0
# 13840     597.0      True           True  128701242.0
# 13842       0.0      True           True   26677287.0
# 13844       0.0      True           True   48053292.0
# 13845   30861.0      True           True   71571206.0
# 13848       0.0      True           True   26018007.0
# 15588       0.0      True           True  956435715.0
# 15590       0.0      True           True  128701242.0
# 15595       0.0      True           True   15110333.0
# 15597       0.0      True           True   26677287.0
#
# [17 rows x 21 columns]

# %% [markdown]
# Vemos que el valor máximo de Speechiness corresponden a grabaciones de ruido blanco o sonidos relajantes para dormir bebés, ya que son contenido sonoro predominantemente no musical.

# %%
spotify_youtube_df[spotify_youtube_df['Speechiness'] == spotify_youtube_df['Speechiness'].max()]
# Out:
#                       Artist  \
# 5158  Sir Arthur Conan Doyle
#
#                                                   Track  \
# 5158  Teil 7 - Sherlock Holmes und der blinde Bettle...
#
#                                                   Album Album_type  \
# 5158  Sherlock Holmes und der blinde Bettler [Die ne...      album
#
#       Danceability  Energy      Key  Loudness  Speechiness  Acousticness  ...  \
# 5158         0.625   0.257  C# / Db   -15.375        0.964         0.115  ...
#
#       Liveness  Valence   Tempo  Duration_ms    Views  Likes  Comments  \
# 5158     0.283    0.349  170.97     180202.0  27263.0  535.0      14.0
#
#       Licensed official_video   Stream
# 5158      True           True  10540.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Acousticness
# Esta columna mide la probabilidad de que una pista sea acustica medida en el rango entre [0.0 ; 1.0],
# 1.0 la pista será con un 100% de probabilidad acústica y 0.0 no habrá probabilidad de que sea acústica

# %%
spotify_youtube_df['Acousticness'].describe()
# Out:
# count    20710.000000
# mean         0.291533
# std          0.286316
# min          0.000001
# 25%          0.045200
# 50%          0.193000
# 75%          0.477000
# max          0.996000
# Name: Acousticness, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df['Acousticness'] == spotify_youtube_df['Acousticness'].max()]
# Out:
#                          Artist  \
# 2757   Pyotr Ilyich Tchaikovsky
# 3638               Joe Hisaishi
# 4056                 Erik Satie
# 4058                 Erik Satie
# 4060                 Erik Satie
# 4290            Johannes Brahms
# 5354            Robert Schumann
# 5356            Robert Schumann
# 5358            Robert Schumann
# 5359            Robert Schumann
# 5360            Robert Schumann
# 6293               Edvard Grieg
# 6297               Edvard Grieg
# 7219                John Powell
# 9027                 Aphex Twin
# 9275                  Lang Lang
# 9780                Max Richter
# 9782                Max Richter
# 14941                      C418
#
#                                                    Track  \
# 2757   Album for the Young, Op. 39: No. 3. Mamma (Maman)
# 3638                                      You're in Love
# 4056                                    Gnossienne No. 1
# 4058                                   Gnossienne: No. 1
# 4060             3 Gymnopédies: No. 1 Lent et douloureux
# 4290   16 Waltzes, Op. 39 (1867 version): No. 15 in A...
# 5354   Kinderszenen, Op. 15: No. 1, Von fremden Lände...
# 5356   Kinderszenen, Op. 15: 1. Von fremden Ländern u...
# 5358                  Kinderszenen, Op. 15: 7. Träumerei
# 5359          Kinderszenen, Op. 15: No. 10 Fast zu ernst
# 5360   Schumann: Kinderszenen, Op. 15: No. 1, Von fre...
# 6293               Lyric Pieces, Book 1, Op. 12: Arietta
# 6297          Lyric Pieces Book I, Op. 12: No. 1 Arietta
# 7219                                     P.S. I Love You
# 9027                                          Avril 14th
# 9275   Orchestral Suite No. 3 in D Major, BWV 1068: I...
# 9780                                       The Departure
# 9782                           A Catalogue of Afternoons
# 14941                                          Wet Hands
#
#                                                    Album Album_type  \
# 2757   Piano Recital: Rosenberger, Carol - Kabalevsky...      album
# 3638                     Howl's Moving Castle Soundtrack      album
# 4056                                    Gnossienne No. 1     single
# 4058   Satie: Avant-dernières pensées (Bonus Track Ve...      album
# 4060                           Satie: The Magic of Satie      album
# 4290    Brahms: Waltzes / Cadenzas / Die Schone Magelone      album
# 5354   Schumann: Kinderszenen; Arabesque; Fantasie; T...      album
# 5356                Schumann: Kinderszenen; Kreisleriana      album
# 5358   Schumann: Kreisleriana; Kinderszenen; Fantasie...      album
# 5359    Schumann: Kinderszenen; Kreisleriana; Waldszenen      album
# 5360   Schumann : Kinderszenen, Waldszenen & Bunte Bl...      album
# 6293   Grieg: Lyric Pieces, Books 1 - 4, Opp. 12, 38,...      album
# 6297                                 Grieg: Lyric Pieces      album
# 7219                                     P.S. I Love You      album
# 9027                                              Drukqs      album
# 9275           Gran Turismo 5 (Original Game Soundtrack)      album
# 9780   The Leftovers: Season 1 (Music from the HBO Se...      album
# 9782                       The Blue Notebooks (15 Years)      album
# 14941                           Minecraft - Volume Alpha      album
#
#        Danceability   Energy      Key  Loudness  Speechiness  Acousticness  \
# 2757          0.418  0.00869        G   -37.257       0.0455         0.996
# 3638          0.526  0.03440        G   -27.855       0.1100         0.996
# 4056          0.376  0.00579        F   -31.615       0.0576         0.996
# 4058          0.424  0.00798        F   -28.345       0.0496         0.996
# 4060          0.590  0.00399        G   -36.497       0.2420         0.996
# 4290          0.406  0.00620        A   -39.131       0.0573         0.996
# 5354          0.374  0.00526        G   -35.546       0.0533         0.996
# 5356          0.282  0.00199        G   -41.932       0.0515         0.996
# 5358          0.404  0.01510        F   -35.799       0.0652         0.996
# 5359          0.456  0.00922        B   -32.721       0.0780         0.996
# 5360          0.279  0.00647        G   -38.339       0.0577         0.996
# 6293          0.427  0.02040  D# / Eb   -31.351       0.0405         0.996
# 6297          0.445  0.00325  D# / Eb   -41.001       0.0581         0.996
# 7219          0.462  0.02940        C   -28.156       0.0481         0.996
# 9027          0.558  0.02590  G# / Ab   -30.016       0.0458         0.996
# 9275          0.500  0.01040        D   -26.764       0.0622         0.996
# 9780          0.384  0.00341        C   -39.053       0.0447         0.996
# 9782          0.124  0.09240        B   -31.726       0.0412         0.996
# 14941         0.616  0.03500        A   -25.836       0.0432         0.996
#
#        ...  Liveness  Valence    Tempo  Duration_ms       Views     Likes  \
# 2757   ...    0.1050   0.4200   87.273      93507.0      5292.0      19.0
# 3638   ...    0.1180   0.2080   67.101      71800.0       596.0      17.0
# 4056   ...    0.0882   0.0369   71.827     296480.0  10545759.0  173981.0
# 4058   ...    0.0983   0.0794  124.166     214133.0  10545759.0  173981.0
# 4060   ...    0.0683   0.1820   74.381     219760.0  40003899.0  691633.0
# 4290   ...    0.0664   0.2160   79.377      85240.0    222713.0    3199.0
# 5354   ...    0.0735   0.3860   69.813      93387.0    223774.0    1685.0
# 5356   ...    0.0625   0.3240  127.892     113240.0    223774.0    1685.0
# 5358   ...    0.0946   0.2820  134.935     150600.0    415188.0    5252.0
# 5359   ...    0.1160   0.0923   65.494      98573.0     33568.0     307.0
# 5360   ...    0.1030   0.2370   67.454     100267.0    223774.0    1685.0
# 6293   ...    0.2740   0.3460  111.242      83227.0    479077.0    3463.0
# 6297   ...    0.0698   0.3730  129.794      87000.0    479077.0    3463.0
# 7219   ...    0.0851   0.3880   79.459      83293.0     38040.0     338.0
# 9027   ...    0.0969   0.3700  157.811     125520.0   3831690.0   25186.0
# 9275   ...    0.0573   0.1330  114.760     327080.0     93471.0     748.0
# 9780   ...    0.0964   0.1170  116.941      75849.0   5331789.0   56417.0
# 9782   ...    0.0935   0.1350  205.999     110880.0    170969.0    1963.0
# 14941  ...    0.0835   0.6430  147.712      90000.0   3650617.0  105153.0
#
#        Comments  Licensed official_video       Stream
# 2757        0.0      True           True   20909481.0
# 3638        0.0     False          False   17963060.0
# 4056     9535.0     False          False   43255565.0
# 4058     9535.0     False          False   48625985.0
# 4060    39823.0     False          False   12716957.0
# 4290      149.0      True           True     969788.0
# 5354       44.0     False          False   12789222.0
# 5356       44.0     False          False    9719644.0
# 5358      102.0     False          False    8683089.0
# 5359        1.0      True           True    4896674.0
# 5360       44.0     False          False    2110799.0
# 6293      128.0     False          False    8296487.0
# 6297      128.0     False          False    2176763.0
# 7219        4.0      True           True   13181774.0
# 9027     4180.0     False          False  149358376.0
# 9275        5.0      True           True   34962333.0
# 9780     1932.0     False          False   86888037.0
# 9782       69.0      True           True   74484448.0
# 14941    2539.0      True           True   55009250.0
#
# [19 rows x 21 columns]

# %% [markdown]
# Comprobamos que todos los valores se encuentran dentro del rango válido, por lo que no hay registros que eliminar. Además revisamos las pistas con valores más altos de Acousticness, confirmando que corresponden a canciones predominantemente acústicas.

# %% [markdown]
# ### Instrumentalness
# Es la columna encagada de indicar si una pista no contiene voces, detecta sonidos como 'oooh' como instrumentales, en este caso, canciones de rap se considerarán totalmente vocales y los valores cercanos a 1.0 indicaran una alta probabilidad de que la pista no tenga contenido vocal.

# %%
spotify_youtube_df['Instrumentalness'].describe()
# Out:
# count    20710.000000
# mean         0.055945
# std          0.193239
# min          0.000000
# 25%          0.000000
# 50%          0.000002
# 75%          0.000463
# max          1.000000
# Name: Instrumentalness, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df['Instrumentalness'] == spotify_youtube_df['Instrumentalness'].max()]
# Out:
#                        Artist                                      Track  \
# 13839  White Noise for Babies  Clean White Noise - Loopable with no fade
# 13840  White Noise for Babies   Pure Brown Noise - Loopable with no fade
# 13842  White Noise for Babies    Air Conditioner - Loopable with no fade
# 13845  White Noise for Babies   Soothing White Noise - Loopable, No Fade
# 13848  White Noise for Babies      Clean White Noise - Loopable, No Fade
# 15588  White Noise Baby Sleep  Clean White Noise - Loopable with no fade
# 15590  White Noise Baby Sleep   Pure Brown Noise - Loopable with no fade
# 15597  White Noise Baby Sleep    Air Conditioner - Loopable with no fade
#
#                                                    Album Album_type  \
# 13839  Best White Noise for Baby Sleep - Loopable wit...      album
# 13840  Best White Noise for Baby Sleep - Loopable wit...      album
# 13842  Best White Noise for Baby Sleep - Loopable wit...      album
# 13845                                        White Noise      album
# 13848                      Relaxing Loopable White Noise     single
# 15588  Best White Noise for Baby Sleep - Loopable wit...      album
# 15590  Best White Noise for Baby Sleep - Loopable wit...      album
# 15597  Best White Noise for Baby Sleep - Loopable wit...      album
#
#        Danceability    Energy      Key  Loudness  Speechiness  Acousticness  \
# 13839           0.0  0.003420  G# / Ab   -28.460          0.0         0.791
# 13840           0.0  0.001250  C# / Db   -27.592          0.0         0.908
# 13842           0.0  0.000055  A# / Bb   -21.995          0.0         0.921
# 13845           0.0  0.001250  C# / Db   -27.592          0.0         0.908
# 13848           0.0  0.003420  G# / Ab   -28.460          0.0         0.791
# 15588           0.0  0.003420  G# / Ab   -28.460          0.0         0.791
# 15590           0.0  0.001250  C# / Db   -27.592          0.0         0.908
# 15597           0.0  0.000055  A# / Bb   -21.995          0.0         0.921
#
#        ...  Liveness  Valence  Tempo  Duration_ms        Views     Likes  \
# 13839  ...     0.111      0.0    0.0      90228.0       1492.0      18.0
# 13840  ...     0.111      0.0    0.0      72223.0    2329675.0   11249.0
# 13842  ...     0.114      0.0    0.0     108527.0        407.0       1.0
# 13845  ...     0.111      0.0    0.0      72223.0  157884163.0  483072.0
# 13848  ...     0.111      0.0    0.0      90228.0       1492.0      18.0
# 15588  ...     0.111      0.0    0.0      90228.0       1492.0      18.0
# 15590  ...     0.111      0.0    0.0      72223.0     290014.0     674.0
# 15597  ...     0.114      0.0    0.0     108527.0        407.0       1.0
#
#        Comments  Licensed official_video       Stream
# 13839       0.0      True           True  956435715.0
# 13840     597.0      True           True  128701242.0
# 13842       0.0      True           True   26677287.0
# 13845   30861.0      True           True   71571206.0
# 13848       0.0      True           True   26018007.0
# 15588       0.0      True           True  956435715.0
# 15590       0.0      True           True  128701242.0
# 15597       0.0      True           True   26677287.0
#
# [8 rows x 21 columns]

# %%
spotify_youtube_df[spotify_youtube_df['Instrumentalness']>0.1]
# Out:
#                Artist                                              Track  \
# 3            Gorillaz                                 On Melancholy Hill
# 6            Gorillaz  New Gold (feat. Tame Impala and Bootie Brown) ...
# 8            Gorillaz                  Cracker Island (feat. Thundercat)
# 32          Metallica                     Master of Puppets (Remastered)
# 52          Daft Punk           Instant Crush (feat. Julian Casablancas)
# ...               ...                                                ...
# 20645  Sleepy Penguin                           White Noise Gentle Piano
# 20653  Sleepy Penguin                          Soothing Baby White Nosie
# 20688       Jung Kook  Left and Right (feat. Jung Kook of BTS) - Inst...
# 20708     SICK LEGEND                     PART OF ME HARDSTYLE (SPED UP)
# 20717     SICK LEGEND                                 MISS YOU HARDSTYLE
#
#                                                    Album Album_type  \
# 3                                          Plastic Beach      album
# 6      New Gold (feat. Tame Impala and Bootie Brown) ...     single
# 8                      Cracker Island (feat. Thundercat)     single
# 32         Master of Puppets (Remastered Deluxe Box Set)      album
# 52                                Random Access Memories      album
# ...                                                  ...        ...
# 20645                    White Noise Piano Calm Melodies      album
# 20653                 White Noise Calming Piano Melodies      album
# 20688  Left and Right (feat. Jung Kook of BTS) [Instr...     single
# 20708                     PART OF ME HARDSTYLE (SPED UP)     single
# 20717                                 MISS YOU HARDSTYLE     single
#
#        Danceability  Energy      Key  Loudness  Speechiness  Acousticness  \
# 3             0.689   0.739        D    -5.810       0.0260      0.000015
# 6             0.716   0.897        E    -7.185       0.0629      0.012000
# 8             0.741   0.913        D    -3.340       0.0465      0.003430
# 32            0.539   0.828        E    -9.108       0.0350      0.000670
# 52            0.775   0.585  A# / Bb    -9.516       0.0271      0.042200
# ...             ...     ...      ...       ...          ...           ...
# 20645         0.315   0.313        D   -21.306       0.0429      0.966000
# 20653         0.379   0.998        C   -24.146       0.1760      0.953000
# 20688         0.899   0.464        D    -8.003       0.0667      0.504000
# 20708         0.642   0.949  A# / Bb    -3.055       0.0373      0.019400
# 20717         0.498   0.938  F# / Gb    -4.543       0.1070      0.002770
#
#        ...  Liveness  Valence    Tempo  Duration_ms        Views      Likes  \
# 3      ...    0.0640   0.5780  120.423     233867.0  211754952.0  1788577.0
# 6      ...    0.3250   0.3580  127.030     274142.0     451996.0    11686.0
# 8      ...    0.3250   0.6430  120.012     213750.0   24459820.0   739527.0
# 32     ...    0.1540   0.5620  105.250     515387.0   20762910.0   293409.0
# 52     ...    0.0770   0.5180  109.942     337560.0  606828966.0  3111505.0
# ...    ...       ...      ...      ...          ...          ...        ...
# 20645  ...    0.1630   0.0000   45.397      31000.0      30371.0       68.0
# 20653  ...    0.6410   0.0000   79.027      31000.0      35534.0      196.0
# 20688  ...    0.0753   0.6540  101.014     152117.0  293367976.0  8016899.0
# 20708  ...    0.4140   0.6920  101.959     112971.0      40814.0      640.0
# 20717  ...    0.1360   0.0787  160.067     181500.0     158697.0     2484.0
#
#        Comments  Licensed official_video       Stream
# 3       55229.0      True           True  434663559.0
# 6         241.0     False           True   10666154.0
# 8       20296.0      True           True   42671901.0
# 32       1703.0      True           True          NaN
# 52      87115.0      True           True  460589724.0
# ...         ...       ...            ...          ...
# 20645       0.0      True           True    7674599.0
# 20653       0.0      True           True    2024411.0
# 20688  540887.0      True           True          NaN
# 20708       0.0      True           True   17721588.0
# 20717       0.0      True           True    5695584.0
#
# [1856 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

spotify_youtube_df['Instrumentalness'].hist(bins=20)
plt.xlabel('Instrumentalness')
plt.ylabel('Canciones')
plt.show()

# %% [markdown]
# Decidimos eliminar la columna dado que la gran mayoria de los valores estan concentrados en 0, prácticamente todas las canciones contienen voces. Esto nos indica que la columna no aporta informacion relevante ni podemos obtener conclusiones significas

# %%
spotify_youtube_df = spotify_youtube_df.drop('Instrumentalness', axis=1)

# %% [markdown]
# ### Liveness
# Esta columna mide de 0 a 1 la presencia de público en el momento de la grabación de la canción.
# Si se acerca a 1 implica que es una canción grabada en directo.

# %%
spotify_youtube_df['Liveness'].describe()
# Out:
# count    20710.000000
# mean         0.193514
# std          0.168541
# min          0.014500
# 25%          0.094100
# 50%          0.125000
# 75%          0.237000
# max          1.000000
# Name: Liveness, dtype: float64

# %% [markdown]
# Como vemos, los valores que toma tienen sentido y están dentro de rango.

# %% [markdown]
# ### Valance
# Mide cuanto de positiva o negativa es emocionalmente una canción. Su valor va de
# 0.0 a 1.0, donde:
#
# ⁠0.0 → canciones tristes, tensas o melancólicas
# 1.0 → canciones alegres, optimistas o eufóricas
#
# Por tanto, cualquier valor menor que 0 o mayor que 1 se considera erróneo.

# %%
spotify_youtube_df["Valence"].describe()
# Out:
# count    20710.000000
# mean         0.529838
# std          0.245438
# min          0.000000
# 25%          0.339000
# 50%          0.537000
# 75%          0.726000
# max          0.993000
# Name: Valence, dtype: float64

# %%
spotify_youtube_df[
    (spotify_youtube_df["Valence"] < 0) |
    (spotify_youtube_df["Valence"] > 1)
]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Liveness, Valence, Tempo, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []

# %% [markdown]
# ### Tempo
# Recogemos los BPM de la canción, es decir, la velocidad a la que va la canción

# %%
spotify_youtube_df['Tempo'].describe()
# Out:
# count    20710.000000
# mean       120.631921
# std         29.577612
# min          0.000000
# 25%         97.002000
# 50%        119.965000
# 75%        139.934750
# max        243.372000
# Name: Tempo, dtype: float64

# %% [markdown]
# Vemos que no hay valores negativos lo que implica que los datos son correctos. Además, el máximo que es 243.37 nos parece un tempo razonable, luego no hay outliers.
# Hemos decidido añadir una columna para entender mejor los datos. Ejemplo: Si Tempo es 29.57 en la nueva columna Tempo_category se recoge como Grave, que en términos musicales implica que va bastante lento.

# %%
def classify_tempo(bpm):
    if bpm < 24:
        return 'Larghissimo'
    elif bpm < 46:
        return 'Grave'
    elif bpm < 61:
        return 'Lento / Largo'
    elif bpm < 77:
        return 'Adagio'
    elif bpm < 109:
        return 'Andante'
    elif bpm < 121:
        return 'Moderato / Allegretto'
    elif bpm < 157:
        return 'Allegro'
    elif bpm < 177:
        return 'Vivace'
    elif bpm < 201:
        return 'Presto'
    else:
        return 'Prestissimo'

# %%
spotify_youtube_df['Tempo_category'] = spotify_youtube_df['Tempo'].apply(classify_tempo)
spotify_youtube_df['Tempo_category']
# Out:
# 0                      Allegro
# 1                      Andante
# 2                      Andante
# 3        Moderato / Allegretto
# 4                       Vivace
#                  ...
# 20713                  Andante
# 20714                   Vivace
# 20715                   Vivace
# 20716                  Allegro
# 20717                   Vivace
# Name: Tempo_category, Length: 20710, dtype: object

# %% [markdown]
# Vamos a ordenar la nueva columna creada para ponerla al lado de la de 'Tempo', para una mejora en la lectura de los catos

# %%
spotify_youtube_df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Valence',
#        'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments', 'Licensed',
#        'official_video', 'Stream', 'Tempo_category'],
#       dtype='object')

# %%
spotify_youtube_df = spotify_youtube_df[['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
       'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Valence',
       'Tempo', 'Tempo_category', 'Duration_ms', 'Views', 'Likes', 'Comments', 'Licensed',
       'official_video', 'Stream']]

# %%
spotify_youtube_df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Valence',
#        'Tempo', 'Tempo_category', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# Vamos a analizar de manera análoga las variables:
# ### ⁠Views
# Número total de visualizaciones del vídeo en YouTube.
# ### ⁠Likes
# Número de "me gusta" que ha recibido el vídeo en YouTube.
# ### ⁠Comments
# Número de comentarios publicados en el vídeo de YouTube.
# ### ⁠Duration_ms
# Duración total de la canción en milisegundos.
#
# Todas estas variables son cuantitativas, de tipo numérico y deben tomar valores
# mayores o iguales a 0, ya que no es posible tener visualizaciones, likes o streams
# negativos. Valores negativos o extremadamente atípicos se considerarían erróneos.

# %%
spotify_youtube_df["Views"].describe()
# Out:
# count    2.024100e+04
# mean     9.394214e+07
# std      2.746823e+08
# min      0.000000e+00
# 25%      1.826290e+06
# 50%      1.450110e+07
# 75%      7.039975e+07
# max      8.079649e+09
# Name: Views, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df["Views"] < 0]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Liveness, Valence, Tempo, Tempo_category, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 21 columns]

# %%
spotify_youtube_df["Likes"].describe()
# Out:
# count    2.017000e+04
# mean     6.633357e+05
# std      1.789538e+06
# min      0.000000e+00
# 25%      2.159050e+04
# 50%      1.244835e+05
# 75%      5.221478e+05
# max      5.078865e+07
# Name: Likes, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df["Likes"] < 0]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Liveness, Valence, Tempo, Tempo_category, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 21 columns]

# %%
spotify_youtube_df["Comments"].describe()
# Out:
# count    2.014200e+04
# mean     2.751929e+04
# std      1.932668e+05
# min      0.000000e+00
# 25%      5.100000e+02
# 50%      3.277500e+03
# 75%      1.436000e+04
# max      1.608314e+07
# Name: Comments, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df["Comments"] < 0]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Liveness, Valence, Tempo, Tempo_category, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 21 columns]

# %%
spotify_youtube_df[spotify_youtube_df["Duration_ms"] < 0]
# Out:
# Empty DataFrame
# Columns: [Artist, Track, Album, Album_type, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Liveness, Valence, Tempo, Tempo_category, Duration_ms, Views, Likes, Comments, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Vemos que no hay valores erróneos en estas variables.

# %% [markdown]
# ### Licensed
# Es una variable boleana. Recoge el valor True si es un vídeo con licencia, y False si no lo es. Hemos visto arriba que tiene 470 valores nulos. Vamos a imputarlos por False, pues creemos que si no podemos saber si tiene licencia implica que no la tiene.

# %%
spotify_youtube_df["Licensed"] = spotify_youtube_df["Licensed"].fillna(False)
spotify_youtube_df['Licensed'].value_counts()
# Out:
# C:\Users\propietario\AppData\Local\Temp\ipykernel_8236\3252406557.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   spotify_youtube_df["Licensed"] = spotify_youtube_df["Licensed"].fillna(False)
# Licensed
# True     14137
# False     6573
# Name: count, dtype: int64

# %% [markdown]
# ### Official video
# Similar a License, es una variable booleana con algunos missing values. Esta variable mide si el vídeo de youtube es el vídeo oficial o no. Vamos a imputar los missings por False porque entendemos que si no se puede saber si es el vídeo oficial o no, entonces no lo es.

# %%
spotify_youtube_df['official_video'] = spotify_youtube_df['official_video'].fillna(False)
spotify_youtube_df['official_video'].value_counts()
# Out:
# C:\Users\propietario\AppData\Local\Temp\ipykernel_8236\2814527519.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   spotify_youtube_df['official_video'] = spotify_youtube_df['official_video'].fillna(False)
# official_video
# True     15718
# False     4992
# Name: count, dtype: int64

# %% [markdown]
# ### Stream
# Indica el número de reproducciones de cada canción en Spotify. Es una medida directa para avaluar la popularidad o el alcance de una cancion

# %%
spotify_youtube_df['Stream'].describe()
# Out:
# count    2.013400e+04
# mean     1.359685e+08
# std      2.441717e+08
# min      6.574000e+03
# 25%      1.767675e+07
# 50%      4.969007e+07
# 75%      1.383581e+08
# max      3.386520e+09
# Name: Stream, dtype: float64

# %%
spotify_youtube_df[spotify_youtube_df['Stream'] == spotify_youtube_df['Stream'].max()]
# Out:
#            Artist            Track        Album Album_type  Danceability  \
# 15250  The Weeknd  Blinding Lights  After Hours      album         0.514
#
#        Energy      Key  Loudness  Speechiness  Acousticness  ...  Valence  \
# 15250    0.73  C# / Db    -5.934       0.0598       0.00146  ...    0.334
#
#          Tempo  Tempo_category Duration_ms        Views      Likes  Comments  \
# 15250  171.005          Vivace    200040.0  674164500.0  8817927.0  282589.0
#
#        Licensed  official_video        Stream
# 15250      True            True  3.386520e+09
#
# [1 rows x 21 columns]

# %%
spotify_youtube_df[spotify_youtube_df['Stream'] == spotify_youtube_df['Stream'].min()]
# Out:
#                    Artist     Track     Album Album_type  Danceability  \
# 8701  I Virtuosi Italiani  Rainbows  Rainbows     single         0.337
#
#       Energy Key  Loudness  Speechiness  Acousticness  ...  Valence   Tempo  \
# 8701   0.328   C   -14.185        0.033         0.948  ...   0.0388  75.435
#
#       Tempo_category Duration_ms  Views  Likes  Comments  Licensed  \
# 8701          Adagio    229248.0  446.0   15.0       2.0      True
#
#       official_video  Stream
# 8701            True  6574.0
#
# [1 rows x 21 columns]

# %% [markdown]
# Para una mejora en la comprension y facilitar la lectura y comprension de los datos, dado que la variable 'Stream' nos proporciona informacion sobre los datos de Spotify, lo colocaremos junto a estos y no separado con los de Youtube

# %%
spotify_youtube_df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Valence',
#        'Tempo', 'Tempo_category', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
spotify_youtube_df= spotify_youtube_df[['Artist', 'Track', 'Album', 'Album_type', 'Stream', 'Danceability', 'Energy',
       'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Valence',
       'Tempo', 'Tempo_category', 'Duration_ms', 'Views', 'Likes', 'Comments',
       'Licensed', 'official_video']]

# %%
spotify_youtube_df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Stream', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Liveness',
#        'Valence', 'Tempo', 'Tempo_category', 'Duration_ms', 'Views', 'Likes',
#        'Comments', 'Licensed', 'official_video'],
#       dtype='object')

# %% [markdown]
# ### Missing values
# Ya hemos imputado las variables Licensed y Official video, vamos a estudiar qué podemos hacer con el resto de variables con missings

# %%
spotify_youtube_df.isnull().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Stream            576
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Liveness            0
# Valence             0
# Tempo               0
# Tempo_category      0
# Duration_ms         0
# Views             469
# Likes             540
# Comments          568
# Licensed            0
# official_video      0
# dtype: int64

# %% [markdown]
# Dado que los missing values son en las variables Views, Likes, Comments, incluso en el propio target Stream siendo estas variables decisivas en nuestro dataset, vamos a estudiar cuál es el % de filas a las que les faltan uno de estos datos.

# %%
missings= spotify_youtube_df[spotify_youtube_df.isnull().any(axis=1)]
missings
# Out:
#           Artist                              Track  \
# 30     Metallica         Enter Sandman (Remastered)
# 31     Metallica  Nothing Else Matters (Remastered)
# 32     Metallica     Master of Puppets (Remastered)
# 34     Metallica        The Unforgiven (Remastered)
# 35     Metallica                   One (Remastered)
# ...          ...                                ...
# 20703   ThxSoMch           Imperfect Girl - Sped Up
# 20704   ThxSoMch                   Like I'm British
# 20705   ThxSoMch        ONLY NEED MY BABY! (SMOAGT)
# 20706   ThxSoMch       HOW YOU ALWAYS LOOK SO GOOD?
# 20707   ThxSoMch               Runaway (Move Quick)
#
#                                                    Album Album_type  Stream  \
# 30                                Metallica (Remastered)      album     NaN
# 31                                Metallica (Remastered)      album     NaN
# 32         Master of Puppets (Remastered Deluxe Box Set)      album     NaN
# 34                                Metallica (Remastered)      album     NaN
# 35     ...And Justice for All (Remastered Deluxe Box ...      album     NaN
# ...                                                  ...        ...     ...
# 20703                                     Imperfect Girl     single     NaN
# 20704                                   Like I'm British     single     NaN
# 20705                        ONLY NEED MY BABY! (SMOAGT)     single     NaN
# 20706                       HOW YOU ALWAYS LOOK SO GOOD?     single     NaN
# 20707                               Runaway (Move Quick)     single     NaN
#
#        Danceability  Energy      Key  Loudness  Speechiness  ...  Liveness  \
# 30            0.566   0.834  F# / Gb    -8.412       0.0298  ...    0.0625
# 31            0.547   0.394        E    -9.793       0.0262  ...    0.0795
# 32            0.539   0.828        E    -9.108       0.0350  ...    0.1540
# 34            0.531   0.583        G    -9.470       0.0256  ...    0.2550
# 35            0.438   0.687        G    -9.150       0.0619  ...    0.4200
# ...             ...     ...      ...       ...          ...  ...       ...
# 20703         0.715   0.885  F# / Gb    -6.269       0.0394  ...    0.1240
# 20704         0.727   0.574  A# / Bb    -6.015       0.1380  ...    0.1160
# 20705         0.704   0.444  G# / Ab   -10.679       0.0473  ...    0.1710
# 20706         0.653   0.631        B    -8.876       0.0758  ...    0.0953
# 20707         0.633   0.257        D   -20.033       0.0532  ...    0.2050
#
#        Valence    Tempo  Tempo_category Duration_ms         Views      Likes  \
# 30       0.621  123.296         Allegro    331560.0  5.735537e+08  2828795.0
# 31       0.170  142.370         Allegro    388733.0  1.209806e+09  5127599.0
# 32       0.562  105.250         Andante    515387.0  2.076291e+07   293409.0
# 34       0.207  139.503         Allegro    387160.0  4.261257e+08  1781690.0
# 35       0.426  103.010         Andante    446146.0  5.240000e+02       18.0
# ...        ...      ...             ...         ...           ...        ...
# 20703    0.675  139.333         Allegro    143851.0  1.076260e+05     2759.0
# 20704    0.378  163.388          Vivace     88966.0  4.036000e+04     1458.0
# 20705    0.448   91.853         Andante     99745.0  3.363600e+04     1282.0
# 20706    0.303   87.642         Andante    128596.0  1.086790e+05     3209.0
# 20707    0.405  144.001         Allegro    112183.0  1.472800e+04      198.0
#
#        Comments  Licensed  official_video
# 30      81335.0      True            True
# 31     135946.0      True            True
# 32       1703.0      True            True
# 34      46392.0     False           False
# 35          1.0     False           False
# ...         ...       ...             ...
# 20703      29.0      True            True
# 20704      14.0      True            True
# 20705      20.0      True            True
# 20706      36.0      True            True
# 20707       2.0      True            True
#
# [1167 rows x 21 columns]

# %% [markdown]
# Hay 1167 filas con valores nulos, de 20710 que es el total de filas

# %%
print( 'El porcentaje de filas con valores nulos es:' , 1167/20710*100, '%')
# Out:
# El porcentaje de filas con valores nulos es: 5.634958957025591 %

# %% [markdown]
# Teniendo en cuenta que tan solo se trata de un 5% de nuestros datos aproximadamenta, consideramos que es más adecuado eliminar las columnas que trabajar con datos imputados que puedan ser erroneos o no sean un reflejo realista de la muestra

# %%
spotify_youtube_df = spotify_youtube_df.drop(missings.index)

# %%
spotify_youtube_df.isnull().sum()
# Out:
# Artist            0
# Track             0
# Album             0
# Album_type        0
# Stream            0
# Danceability      0
# Energy            0
# Key               0
# Loudness          0
# Speechiness       0
# Acousticness      0
# Liveness          0
# Valence           0
# Tempo             0
# Tempo_category    0
# Duration_ms       0
# Views             0
# Likes             0
# Comments          0
# Licensed          0
# official_video    0
# dtype: int64

# %%
spotify_youtube_df.shape
# Out:
# (19543, 21)

# %%
spotify_youtube_df.head()
# Out:
#      Artist                                          Track  \
# 0  Gorillaz                                 Feel Good Inc.
# 1  Gorillaz                                Rhinestone Eyes
# 2  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                             On Melancholy Hill
# 4  Gorillaz                                 Clint Eastwood
#
#                                            Album Album_type        Stream  \
# 0                                     Demon Days      album  1.040235e+09
# 1                                  Plastic Beach      album  3.100837e+08
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single  6.306347e+07
# 3                                  Plastic Beach      album  4.346636e+08
# 4                                       Gorillaz      album  6.172597e+08
#
#    Danceability  Energy      Key  Loudness  Speechiness  ...  Liveness  \
# 0         0.818   0.705  F# / Gb    -6.679       0.1770  ...    0.6130
# 1         0.676   0.703  G# / Ab    -5.815       0.0302  ...    0.0463
# 2         0.695   0.923  C# / Db    -3.930       0.0522  ...    0.1160
# 3         0.689   0.739        D    -5.810       0.0260  ...    0.0640
# 4         0.663   0.694  A# / Bb    -8.627       0.1710  ...    0.0698
#
#    Valence    Tempo         Tempo_category Duration_ms        Views  \
# 0    0.772  138.559                Allegro    222640.0  693555221.0
# 1    0.852   92.761                Andante    200173.0   72011645.0
# 2    0.551  108.014                Andante    215150.0    8435055.0
# 3    0.578  120.423  Moderato / Allegretto    233867.0  211754952.0
# 4    0.525  167.953                 Vivace    340920.0  618480958.0
#
#        Likes  Comments  Licensed  official_video
# 0  6220896.0  169907.0      True            True
# 1  1079128.0   31003.0      True            True
# 2   282142.0    7399.0      True            True
# 3  1788577.0   55229.0      True            True
# 4  6197318.0  155930.0      True            True
#
# [5 rows x 21 columns]

# %% [markdown]
# Correlación:

# %% [markdown]
# Para estudiar cómo se relacionan las variables numéricas entre sí, calculamos la matriz de correlación y lo representamos mediante un mapa de calor.

# %%
spotify_youtube_df.corr(numeric_only=True)
# Out:
#                   Stream  Danceability    Energy  Loudness  Speechiness  \
# Stream          1.000000      0.071969  0.044840  0.119182    -0.016266
# Danceability    0.071969      1.000000  0.238029  0.357748     0.226504
# Energy          0.044840      0.238029  1.000000  0.745225     0.088834
# Loudness        0.119182      0.357748  0.745225  1.000000     0.068120
# Speechiness    -0.016266      0.226504  0.088834  0.068120     1.000000
# Acousticness   -0.104080     -0.281453 -0.662349 -0.553120    -0.098102
# Liveness       -0.037437     -0.083322  0.174243  0.086959     0.065957
# Valence        -0.012833      0.463108  0.391836  0.316069     0.060513
# Tempo           0.002624     -0.063050  0.155054  0.142496     0.050459
# Duration_ms    -0.011588     -0.089295  0.024028  0.012006    -0.049348
# Views           0.602587      0.088324  0.067181  0.118338    -0.010000
# Likes           0.654950      0.098483  0.062742  0.123641     0.012538
# Comments        0.267863      0.043407  0.045246  0.059168     0.010128
# Licensed        0.104799      0.006335  0.084893  0.103187    -0.065254
# official_video  0.103978      0.037826  0.112840  0.145889    -0.056710
#
#                 Acousticness  Liveness   Valence     Tempo  Duration_ms  \
# Stream             -0.104080 -0.037437 -0.012833  0.002624    -0.011588
# Danceability       -0.281453 -0.083322  0.463108 -0.063050    -0.089295
# Energy             -0.662349  0.174243  0.391836  0.155054     0.024028
# Loudness           -0.553120  0.086959  0.316069  0.142496     0.012006
# Speechiness        -0.098102  0.065957  0.060513  0.050459    -0.049348
# Acousticness        1.000000 -0.052414 -0.205772 -0.129139    -0.024751
# Liveness           -0.052414  1.000000  0.031926  0.008364    -0.000970
# Valence            -0.205772  0.031926  1.000000  0.091915    -0.050596
# Tempo              -0.129139  0.008364  0.091915  1.000000    -0.013941
# Duration_ms        -0.024751 -0.000970 -0.050596 -0.013941     1.000000
# Views              -0.070420 -0.016524  0.037246 -0.001255     0.021914
# Likes              -0.078664 -0.023111  0.012750  0.002346     0.006223
# Comments           -0.052981 -0.012904  0.017957  0.008019    -0.001175
# Licensed           -0.074285 -0.000903  0.012513  0.009539     0.029813
# official_video     -0.090886  0.003759  0.004028  0.020941     0.004628
#
#                    Views     Likes  Comments  Licensed  official_video
# Stream          0.602587  0.654950  0.267863  0.104799        0.103978
# Danceability    0.088324  0.098483  0.043407  0.006335        0.037826
# Energy          0.067181  0.062742  0.045246  0.084893        0.112840
# Loudness        0.118338  0.123641  0.059168  0.103187        0.145889
# Speechiness    -0.010000  0.012538  0.010128 -0.065254       -0.056710
# Acousticness   -0.070420 -0.078664 -0.052981 -0.074285       -0.090886
# Liveness       -0.016524 -0.023111 -0.012904 -0.000903        0.003759
# Valence         0.037246  0.012750  0.017957  0.012513        0.004028
# Tempo          -0.001255  0.002346  0.008019  0.009539        0.020941
# Duration_ms     0.021914  0.006223 -0.001175  0.029813        0.004628
# Views           1.000000  0.892078  0.431444  0.151261        0.140105
# Likes           0.892078  1.000000  0.631544  0.151053        0.145624
# Comments        0.431444  0.631544  1.000000  0.061428        0.055227
# Licensed        0.151261  0.151053  0.061428  1.000000        0.814190
# official_video  0.140105  0.145624  0.055227  0.814190        1.000000

# %%
corr = spotify_youtube_df.corr(numeric_only=True)
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# La matriz de correlación y el mapa de calor muestra patrones claros entre las variables numericas:
#
# - Métricas de YouTube (Views, Likes y Comments) están fuertemente correlacionadas entre sí, especialmente Views–Likes (0.89)
# - Streams en Spotify presenta correlación moderada Views (0.60) y con Likes (0.65), lo que indica que la popularidad suele ser similar en ambas plataformas.
# - Entre las características de audio destacan:
#
#     -Energy–Loudness (0.74), relación lógica entre intensidad y volumen.
#
#     -Energy–Acousticness (–0.66), canciones acústicas tienden a ser menos energéticas.
#
#     -Danceability–Valence (0.46), canciones más bailables suelen sonar más positivas.
#
# - Variables como Tempo, Duration_ms, Liveness o Speechiness muestran poca relación con Streams, Views y Likes
# - Licensed y official_video tienen alta correlación entre sí (0.81), como es esperable.

# %% [markdown]
# ## Conclusiones del dataset
#
# Creemos que es un buen dataset ya que:
# - Tras los cambios no hay missing values
# - Hay mucha correlación entre las variables lo que nos indica que los datos son coherentes entre sí
# - Los datos que están relacionados están escritos en la misma escala como en la columna liveness, valance... que están escritos en (0,1)
# - No hemos acotado los valores superiores porque creemos que de esta manera somos más fieles al mundo actu
